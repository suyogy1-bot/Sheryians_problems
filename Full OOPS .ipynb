# %% [markdown]
# Multilevel Inheritance – Employee Hierarchy
#
#     Problem Statement
#
#     Create:
#
#     Person
#     Employee
#     Manager
#
#     Display all employee details.
#
#      Output:
#      Name : Amit
#      Salary : 50000
#      Department : IT

# %%
#Write a code

# %% [markdown]
# Using super() Function
#
#     Problem Statement
#
#     Create:
#
#     Vehicle
#     Car
#
#     Use super() to access parent constructor.
#
#
#     Output:
#     Brand : Toyota
#     Model : Fortuner

# %%
#Write a code

# %% [markdown]
# Encapsulation – Bank Account
#
#     Problem Statement
#
#     Create a private balance variable and access it using methods.
#
#     Output:
#     Final Price = 45000.0

# %%
#Write a code

# %% [markdown]
# Hospital Management System
#
#     Problem Statement
#
#     Create:
#
#     Person
#     Doctor
#     Patient
#
#     Display all information.
#
#     Output:
#     Doctor : Sharma
#     Specialization : Cardiologist

# %%
#Write a code

# %% [markdown]
# Polymorphism – Shape Area
#
#     Problem Statement
#
#      Create:
#
#      Rectangle
#      Circle
#
#      Both should have area() method.
#
#      Output:
#      Area = 50
#      Area = 153.86

# %%
#Write a code

# %% [markdown]
# Online Shopping System
#
#     Problem Statement
#
#     Create:
#
#     Product
#     Electronics Product
#
#   Apply discount calculation.
#
#     Output: Final Price = 45000.0

# %%
#Write a code
