# %% [markdown]
# # Python OOPs Assignment — Classes & Functions
#
# ## Level: Intermediate to Advanced
#
# ### Topics Covered
# - Classes
# - Objects
# - Constructors (__init__)
# - Instance Variables
# - Methods
# - self Keyword
# - User Defined Functions

# %% [markdown]
# # Q1. Student Report Card
#
# ## Problem Statement
# Create a Student class. Store name and 3 subject marks. Create methods to calculate total and average.
#
# ## Sample Input
# ```python
# Name: Aman
# Maths: 80
# Science: 75
# English: 85
# ```
#
# ## Sample Output
# ```python
# Name: Aman
# Total Marks: 240
# Average Marks: 80.0
# ```

# %%
# Write your code here

# %% [markdown]
# # Q2. Bank Account Manager
#
# ## Problem Statement
# Create a BankAccount class. Create deposit(), withdraw() and display_balance() methods.
#
# ## Sample Input
# ```python
# Balance: 10000
# Deposit: 2000
# Withdraw: 1500
# ```
#
# ## Sample Output
# ```python
# Current Balance: 10500
# ```

# %%
# Write your code here

# %% [markdown]
# # Q3. Rectangle Calculator
#
# ## Problem Statement
# Create a Rectangle class. Create area() and perimeter() methods.
#
# ## Sample Input
# ```python
# Length: 10
# Breadth: 5
# ```
#
# ## Sample Output
# ```python
# Area: 50
# Perimeter: 30
# ```

# %%
# Write your code here

# %% [markdown]
# # Q4. Employee Salary System
#
# ## Problem Statement
# Create an Employee class. Calculate 10% bonus using a method.
#
# ## Sample Input
# ```python
# Name: Rahul
# Salary: 50000
# ```
#
# ## Sample Output
# ```python
# Employee: Rahul
# Bonus: 5000
# ```

# %%
# Write your code here

# %% [markdown]
# # Q5. Product Billing System
#
# ## Problem Statement
# Create a Product class. Calculate total bill using price and quantity.
#
# ## Sample Input
# ```python
# Product: Laptop
# Price: 50000
# Quantity: 2
# ```
#
# ## Sample Output
# ```python
# Total Bill: 100000
# ```

# %%
# Write your code here

# %% [markdown]
# # Q6. Circle Calculator
#
# ## Problem Statement
# Create a Circle class. Calculate area and circumference.
#
# ## Sample Input
# ```python
# Radius: 7
# ```
#
# ## Sample Output
# ```python
# Area: 153.86
# Circumference: 43.96
# ```

# %%
# Write your code here

# %% [markdown]
# # Q7. Movie Rating System
#
# ## Problem Statement
# Create a Movie class. If rating > 8 print Excellent else Good.
#
# ## Sample Input
# ```python
# Movie: Leo
# Rating: 8.5
# ```
#
# ## Sample Output
# ```python
# Movie: Leo
# Category: Excellent
# ```

# %%
# Write your code here

# %% [markdown]
# # Q8. Library Book Manager
#
# ## Problem Statement
# Create a Book class and display all details using a method.
#
# ## Sample Input
# ```python
# Book: Python Basics
# Author: Robert
# Price: 499
# ```
#
# ## Sample Output
# ```python
# Book: Python Basics
# Author: Robert
# Price: 499
# ```

# %%
# Write your code here

# %% [markdown]
# # Q9. Electricity Bill Calculator
#
# ## Problem Statement
# Create an ElectricityBill class. Bill = Units * 8
#
# ## Sample Input
# ```python
# Units: 120
# ```
#
# ## Sample Output
# ```python
# Total Bill: 960
# ```

# %%
# Write your code here

# %% [markdown]
# # Q10. Online Course Tracker
#
# ## Problem Statement
# Create a Course class and calculate progress percentage.
#
# ## Sample Input
# ```python
# Course: Python
# Total Lectures: 100
# Completed Lectures: 65
# ```
#
# ## Sample Output
# ```python
# Course: Python
# Progress: 65.0%
# ```

# %%
# Write your code here
